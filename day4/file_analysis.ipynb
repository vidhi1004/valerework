# %%
import pandas 
import json
import csv
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
with open(r"C:\Users\Administrator\Desktop\valere labs\day4\practice3.csv", "r") as f:
    data=f.read()
    print(data)
# Out:
# Order ID,Date,Customer Name,Product Name,Category,Quantity,Unit Price,Total Sales,Discount,Profit,Region
# ORD1000,2024-03-06,Travis Kennedy,Football,Sports,2,170.71,341.42,25.59,56.46,Central
# ORD1001,2024-12-01,Stacey Allison,Rice,Grocery,9,277.2,2494.8,228.62,430.07,East
# ORD1002,2024-02-11,Todd Moore,Bookshelf,Furniture,6,81.08,486.48,81.8,166.88,South
# ORD1003,2024-12-09,Keith Beard,Jacket,Clothing,9,25.9,233.1,34.02,43.06,East
# ORD1004,2024-11-06,Patrick Frost,Headphones,Electronics,4,144.89,579.56,4.94,228.06,Central
# ORD1005,2024-07-09,Jessica Robinson,Smartphone,Electronics,9,458.75,4128.75,272.11,1353.93,Central
# ORD1006,2024-11-21,Taylor Johnson,Smartwatch,Electronics,2,451.89,903.78,144.81,393.84,North
# ORD1007,2024-08-06,Ruth Scott,Jacket,Clothing,1,41.95,41.95,0.24,5.97,West
# ORD1008,2024-03-20,Ruth Ellis,T-shirt,Clothing,6,463.5,2781,513.96,403.53,South
# ORD1009,2024-07-10,Steven Martin,Gym Gloves,Sports,3,65.91,197.73,18.31,77.55,North
# ...

# %%
with open (r"C:\Users\Administrator\Desktop\valere labs\day4\practice3.csv","r") as csv_file:
    data=csv.reader(csv_file)
    
    for r in data:
        print(r)
# Out:
# ['Order ID', 'Date', 'Customer Name', 'Product Name', 'Category', 'Quantity', 'Unit Price', 'Total Sales', 'Discount', 'Profit', 'Region']
# ['ORD1000', '2024-03-06', 'Travis Kennedy', 'Football', 'Sports', '2', '170.71', '341.42', '25.59', '56.46', 'Central']
# ['ORD1001', '2024-12-01', 'Stacey Allison', 'Rice', 'Grocery', '9', '277.2', '2494.8', '228.62', '430.07', 'East']
# ['ORD1002', '2024-02-11', 'Todd Moore', 'Bookshelf', 'Furniture', '6', '81.08', '486.48', '81.8', '166.88', 'South']
# ['ORD1003', '2024-12-09', 'Keith Beard', 'Jacket', 'Clothing', '9', '25.9', '233.1', '34.02', '43.06', 'East']
# ['ORD1004', '2024-11-06', 'Patrick Frost', 'Headphones', 'Electronics', '4', '144.89', '579.56', '4.94', '228.06', 'Central']
# ['ORD1005', '2024-07-09', 'Jessica Robinson', 'Smartphone', 'Electronics', '9', '458.75', '4128.75', '272.11', '1353.93', 'Central']
# ...

# %%
df=pandas.read_csv(r"C:\Users\Administrator\Desktop\valere labs\day4\practice3.csv")

# %%
df
# Out:
#    Order ID        Date        Customer Name   Product Name     Category  \
# 0   ORD1000  2024-03-06       Travis Kennedy       Football       Sports
# 1   ORD1001  2024-12-01       Stacey Allison           Rice      Grocery
# 2   ORD1002  2024-02-11           Todd Moore      Bookshelf    Furniture
# 3   ORD1003  2024-12-09          Keith Beard         Jacket     Clothing
# 4   ORD1004  2024-11-06        Patrick Frost     Headphones  Electronics
# ..      ...         ...                  ...            ...          ...
# 95  ORD1095  2024-06-16        Jeffrey Cohen         Laptop  Electronics
# 96  ORD1096  2024-04-22       Joshua Collins          Shoes     Clothing
# 97  ORD1097  2024-09-05  Stephanie Jefferson  Tennis Racket       Sports
# 98  ORD1098  2024-06-24    Stephanie Pacheco         Tablet  Electronics
# 99  ORD1099  2025-01-24        Andrea Gamble     Smartphone  Electronics
#
#     Quantity  Unit Price  Total Sales  Discount  Profit   Region
# ...

# %%
df.describe()
# Out:
#          Quantity  Unit Price  Total Sales    Discount       Profit
# count  100.000000  100.000000    100.00000  100.000000   100.000000
# mean     5.770000  232.743800   1350.98730  138.394000   404.460900
# std      2.856342  140.909726   1113.57967  148.348163   403.460792
# min      1.000000   13.170000     37.64000    0.240000     5.970000
# 25%      3.000000  119.122500    389.49500   24.487500   116.142500
# 50%      6.000000  220.625000    965.22500   74.065000   290.280000
# 75%      8.000000  333.515000   2111.91500  220.010000   500.667500
# max     10.000000  497.440000   4128.75000  534.670000  1627.530000

# %%
df.head(5)
# Out:
#   Order ID        Date   Customer Name Product Name     Category  Quantity  \
# 0  ORD1000  2024-03-06  Travis Kennedy     Football       Sports         2
# 1  ORD1001  2024-12-01  Stacey Allison         Rice      Grocery         9
# 2  ORD1002  2024-02-11      Todd Moore    Bookshelf    Furniture         6
# 3  ORD1003  2024-12-09     Keith Beard       Jacket     Clothing         9
# 4  ORD1004  2024-11-06   Patrick Frost   Headphones  Electronics         4
#
#    Unit Price  Total Sales  Discount  Profit   Region
# 0      170.71       341.42     25.59   56.46  Central
# 1      277.20      2494.80    228.62  430.07     East
# 2       81.08       486.48     81.80  166.88    South
# 3       25.90       233.10     34.02   43.06     East
# 4      144.89       579.56      4.94  228.06  Central

# %%
df.tail()
# Out:
#    Order ID        Date        Customer Name   Product Name     Category  \
# 95  ORD1095  2024-06-16        Jeffrey Cohen         Laptop  Electronics
# 96  ORD1096  2024-04-22       Joshua Collins          Shoes     Clothing
# 97  ORD1097  2024-09-05  Stephanie Jefferson  Tennis Racket       Sports
# 98  ORD1098  2024-06-24    Stephanie Pacheco         Tablet  Electronics
# 99  ORD1099  2025-01-24        Andrea Gamble     Smartphone  Electronics
#
#     Quantity  Unit Price  Total Sales  Discount  Profit   Region
# 95         1      164.46       164.46     22.23   38.99     West
# 96         1      271.25       271.25     17.87   82.93  Central
# 97         8       13.17       105.36      1.99   21.52     East
# 98         9      200.17      1801.53    310.36  825.88    North
# 99         8      291.46      2331.68    439.95  422.28    North

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       100 non-null    object
#  1   Date           100 non-null    object
#  2   Customer Name  100 non-null    object
#  3   Product Name   100 non-null    object
#  4   Category       100 non-null    object
#  5   Quantity       100 non-null    int64
#  6   Unit Price     100 non-null    float64
#  7   Total Sales    100 non-null    float64
#  8   Discount       100 non-null    float64
#  9   Profit         100 non-null    float64
#  10  Region         100 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 8.7+ KB

# %%
df.isnull()
# Out:
#     Order ID   Date  Customer Name  Product Name  Category  Quantity  \
# 0      False  False          False         False     False     False
# 1      False  False          False         False     False     False
# 2      False  False          False         False     False     False
# 3      False  False          False         False     False     False
# 4      False  False          False         False     False     False
# ..       ...    ...            ...           ...       ...       ...
# 95     False  False          False         False     False     False
# 96     False  False          False         False     False     False
# 97     False  False          False         False     False     False
# 98     False  False          False         False     False     False
# 99     False  False          False         False     False     False
#
#     Unit Price  Total Sales  Discount  Profit  Region
# 0        False        False     False   False   False
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Date', 'Customer Name', 'Product Name', 'Category',
#        'Quantity', 'Unit Price', 'Total Sales', 'Discount', 'Profit',
#        'Region'],
#       dtype='object')

# %%
df.dropna()
# Out:
#    Order ID        Date        Customer Name   Product Name     Category  \
# 0   ORD1000  2024-03-06       Travis Kennedy       Football       Sports
# 1   ORD1001  2024-12-01       Stacey Allison           Rice      Grocery
# 2   ORD1002  2024-02-11           Todd Moore      Bookshelf    Furniture
# 3   ORD1003  2024-12-09          Keith Beard         Jacket     Clothing
# 4   ORD1004  2024-11-06        Patrick Frost     Headphones  Electronics
# ..      ...         ...                  ...            ...          ...
# 95  ORD1095  2024-06-16        Jeffrey Cohen         Laptop  Electronics
# 96  ORD1096  2024-04-22       Joshua Collins          Shoes     Clothing
# 97  ORD1097  2024-09-05  Stephanie Jefferson  Tennis Racket       Sports
# 98  ORD1098  2024-06-24    Stephanie Pacheco         Tablet  Electronics
# 99  ORD1099  2025-01-24        Andrea Gamble     Smartphone  Electronics
#
#     Quantity  Unit Price  Total Sales  Discount  Profit   Region
# ...

# %%
df['Quantity'].unique()
# Out:
# array([ 2,  9,  6,  4,  1,  3, 10,  5,  7,  8], dtype=int64)

# %%
df.Category.unique()
# Out:
# array(['Sports', 'Grocery', 'Furniture', 'Clothing', 'Electronics'],
#       dtype=object)

# %%
df['Quantity'].min()
# Out:
# 1

# %%
df['Total Sales'].min()
# Out:
# 37.64

# %%
df['Total Sales'].max()
# Out:
# 4128.75

# %%
df['Product Name'].unique()
# Out:
# array(['Football', 'Rice', 'Bookshelf', 'Jacket', 'Headphones',
#        'Smartphone', 'Smartwatch', 'T-shirt', 'Gym Gloves', 'Bread',
#        'Table', 'Laptop', 'Tablet', 'Basketball', 'Tennis Racket',
#        'Cricket Bat', 'Shoes', 'Bed', 'Vegetables', 'Jeans', 'Milk',
#        'Sweater', 'Chair', 'Fruits'], dtype=object)

# %%
df['Category'].unique().max()
# Out:
# 'Sports'

# %%
df['Region'].unique().min()
# Out:
# 'Central'

# %%
df['Country'] = 'USA'

# %%
df
# Out:
#    Order ID        Date        Customer Name   Product Name     Category  \
# 0   ORD1000  2024-03-06       Travis Kennedy       Football       Sports
# 1   ORD1001  2024-12-01       Stacey Allison           Rice      Grocery
# 2   ORD1002  2024-02-11           Todd Moore      Bookshelf    Furniture
# 3   ORD1003  2024-12-09          Keith Beard         Jacket     Clothing
# 4   ORD1004  2024-11-06        Patrick Frost     Headphones  Electronics
# ..      ...         ...                  ...            ...          ...
# 95  ORD1095  2024-06-16        Jeffrey Cohen         Laptop  Electronics
# 96  ORD1096  2024-04-22       Joshua Collins          Shoes     Clothing
# 97  ORD1097  2024-09-05  Stephanie Jefferson  Tennis Racket       Sports
# 98  ORD1098  2024-06-24    Stephanie Pacheco         Tablet  Electronics
# 99  ORD1099  2025-01-24        Andrea Gamble     Smartphone  Electronics
#
#     Quantity  Unit Price  Total Sales  Discount  Profit   Region Country
# ...
